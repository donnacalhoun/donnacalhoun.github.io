# %%
from pybtex.database.input import bibtex
import os

import pandas as pd
from nameparser import HumanName

# %%
df = pd.read_csv("students.tsv", sep="\t", header=0)
display(df)
display(df.columns)
# Out:
#    name-first     name-last type  \
# 0    Patricia         Azike  phd
# 1       Damyn       Chipman  phd
# 2       Brian        Kyanjo  phd
# 3       Talin  Mirzakhanian   ms
# 4        John      Hutchins   ms
# 5        Jean     Schneider   ms
# 6         Gus        Tropea   ms
# 7    Augustus        Tropea  phd
# 8      Hannah         Spero   bs
# 9       Scott         Aiton   bs
# 10      Tyler        Qualls   bs
# 11     Antone   Chacartegui   bs
# 12    Brenton          Peck   bs
# 13     Jordan      Engstrom   bs
# 14      Aaron          Solt   bs
# 15       Cody     Casteneda   bs
# 16  Stephanie        Potter   bs
# 17    Anthony       Jimenez   bs
# 18       Zack  Christiansen   ms
#
#                                               program   start-date  \
# 0                                    PhD in Computing    Fall 2021
# 1                                    PhD in Computing          NaN
# 2                                    PhD in Computing          NaN
# 3                                   MS in Mathematics          NaN
# 4                                   MS in Mathematics          NaN
# 5                                   MS in Mathematics          NaN
# 6                                   MS in Mathematics          NaN
# 7                                    PhD in Computing    Fall 2023
# 8                                   BS in Geosciences  Spring 2018
# 9   BS in Applied Mathematics, Physics and Compute...          NaN
# 10            BS in Applied Mathematics and Economics          NaN
# 11                          BS in Applied Mathematics  Spring 2020
# 12                          BS in Applied Mathematics          NaN
# 13                                  BS in Geosciences          NaN
# 14                          BS in Applied Mathematics          NaN
# 15                       BS in Mechanical Engineering          NaN
# 16                          BS in Applied Mathematics          NaN
# 17                                  BS in Mathematics          NaN
# 18                                  MS in Mathematics          NaN
#
#    graduation-date                                            project  \
# 0          present    Data assimilation for wildfire smoke simulation
# 1      Summer 2024  Direct elliptic solvers for adaptively refined...
# 2      Summer 2024  Work focused on developing ForestClaw for atmo...
# 3      Spring 2017                                                NaN
# 4      Summer 2013                                                NaN
# 5      Summer 2012                                                NaN
# 6      Summer 2024                             Atmospheric Lamb Waves
# 7          present                             Atmospheric Lamb Waves
# 8      Spring 2021  Develop computational model of the 1976 Teton ...
# 9      Spring 2020  Developed a multigrid solver for elliptic prob...
# 10     Spring 2021  Modeling Fractal Urban Growth Through Reaction...
# 11         present  Tensor analysis on the sphere (HERC Fellowship...
# 12     Spring 2018       Direct solvers for 3d adaptive octree meshes
# 13       Fall 2017                                                NaN
# 14       Fall 2015  Schemes for maintaining conservation in the pa...
# 15       Fall 2015  Work with Idaho National Laboratory to develop...
# 16       Fall 2015  Google Earth visualization of tsunami activity...
# 17     Spring 2023  Automatic Differentiation using Dual Numbers (...
# 18       Fall 2023    “Cosine Similarity and Hierarchical Clustering”
#
#                                                thesis  \
# 0                                                 NaN
# 1   “An Adaptive and Parallel Direct Solver for El...
# 2   “GEOFLOOD: COMPUTATIONAL MODEL FOR OVERLAND FL...
# 3   “Multi-rate Runge-Kutta-Chebyshev Time Steppin...
# 4   “Computing curvature and curvature normals on ...
# 5   “Perfect stripes from a general Turing model i...
# 6   “Numerical Simulation of the Atmospheric Lamb ...
# 7                                                 NaN
# 8   “Validating GeoClaw for Simulating Teton Dam F...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  “Petrogenesis and Thermodynamic Modeling of Ma...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
#
#                         funding  Unnamed: 9  Unnamed: 10
# 0                           NSF         NaN          NaN
# 1                           NSF         NaN          NaN
# 2                          NASA         NaN          NaN
# 3                           NSF         NaN          NaN
# 4            teaching assistant         NaN          NaN
# 5            teaching assistant         NaN          NaN
# 6            teaching assistant         NaN          NaN
# 7            teaching assistant         NaN          NaN
# 8                           NSF         NaN          NaN
# 9                           NSF         NaN          NaN
# 10                          NaN         NaN          NaN
# 11  HERC Fellowship recipient.          NaN          NaN
# 12                          NSF         NaN          NaN
# 13                          NaN         NaN          NaN
# 14                          NaN         NaN          NaN
# 15                          NSF         NaN          NaN
# 16                          NaN         NaN          NaN
# 17                          NaN         NaN          NaN
# 18                          NaN         NaN          NaN
# Index(['name-first', 'name-last', 'type', 'program', 'start-date',
#        'graduation-date', 'project', 'thesis', 'funding', 'Unnamed: 9',
#        'Unnamed: 10'],
#       dtype='object')

# %%
student_program_list = df.program.unique()
print(student_program_list)
# Out:
# ['PhD in Computing' 'MS in Mathematics' 'BS in Geosciences'
#  'BS in Applied Mathematics, Physics and Computer Science'
#  'BS in Applied Mathematics and Economics' 'BS in Applied Mathematics'
#  'BS in Mechanical Engineering' 'BS in Mathematics']

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
# df_journals = df[df['journal'].isnull() == False]
def single_quote(s):
    return "'" + s + "'"

def double_quote(s):
    return "\"" + s + "\""

def endl():
    return "\n"

def br():
    return "<br/>"

for row, item in df.iterrows():    
    first_name = item['name-first']
    last_name = item['name-last']
    type_name = item['type']
    fname = f"{first_name:}-{last_name:}"
    md_filename = f"{fname:}.md"
    html_filename = f"{fname:}.html"
    start_date = item['start-date']
    grad_date = item['graduation-date']

    
    
    ## YAML variables
    
    md = "---" + endl()
    # ------
    # name: 
    # ------
    md += "name: " + single_quote(f"{first_name:} {last_name:}") + endl()
    
    # -----------
    # collection: 
    # -----------
    md += "collection: students" + endl()

    # -----------
    # Type:
    # -----------

    md += "type: " + item['type'] + endl()
    
    # -----------
    # Program:
    # -----------
    
    md += "program: " + double_quote(item['program']) + endl()
    
    # ----------
    # permalink: 
    # ----------
    md += 'permalink: /students/' + html_filename + endl()
    
    # ---------
    # project:
    # ---------
    if not pd.isna(item['thesis']):
        md += "thesis: " + single_quote(html_escape(item['thesis'])) + endl()
    elif not pd.isna(item['project']):
        md += "project: " + single_quote(html_escape(item['project'])) + endl()    

    # ---------
    # funding:
    # ---------
    if not pd.isna(item['funding']):
        md += 'funding: ' + single_quote(item['funding']) + endl()
        
                
    # -----
    # date: 
    # -----
    
    if not pd.isna(item['start-date']):
        start_date = item['start-date']
        md += "dates: " + single_quote(start_date + ' - present') + endl()
    else:
        grad_date = item['graduation-date']
        md += "dates: " + single_quote(grad_date) + endl()
                        
    md += "---" + endl()
    
    
    print(fname)
    print("")

    
    # ----------------------------------------
    # Markdown description for individual page
    # ----------------------------------------
    
    # Put miscellaneous content here
    
    # md += ...
    
    # ----------------------------------------
    # Write out file name
    # ----------------------------------------

    md_filename = os.path.basename(md_filename)
       
    with open("../_students/" + md_filename, 'w') as f:
        f.write(md)    
        
print("Success!")
# Out:
# Patricia-Azike
#
# Damyn-Chipman
#
# Brian-Kyanjo
#
# Talin-Mirzakhanian
#
# John-Hutchins
#
# Jean-Schneider
#
# Gus-Tropea
#
# Augustus-Tropea
#
# Hannah-Spero
#
# Scott-Aiton
#
# Tyler-Qualls
#
# Antone-Chacartegui
#
# Brenton-Peck
#
# Jordan-Engstrom
#
# Aaron-Solt
#
# Cody-Casteneda
#
# Stephanie-Potter
#
# Anthony-Jimenez
#
# Zack-Christiansen
#
# Success!

# %%
print("Done")
# Out:
# Done
