# %%
from pybtex.database.input import bibtex
import os

import pandas as pd
from nameparser import HumanName

# %%
df = pd.read_csv("students.tsv", sep="\t", header=0)
display(df)
display(df.columns)
# Out:
#    name-first     name-last type  \
# 0    Patricia         Azike  phd
# 1       Damyn       Chipman  phd
# 2       Brian        Kyanjo  phd
# 3       Talin  Mirzakhanian   ms
# 4        John      Hutchins   ms
# 5        Jean     Schneider   ms
# 6         Gus        Tropea   ms
# 7      Hannah         Spero   bs
# 8       Scott         Aiton   bs
# 9       Tyler        Qualls   bs
# 10     Antone   Chacartegui   bs
# 11    Brenton          Peck   bs
# 12     Jordan      Engstrom   bs
# 13      Aaron          Solt   bs
# 14       Cody     Casteneda   bs
# 15  Stephanie        Potter   bs
# 16    Anthony       Jimenez   bs
#
#                                               program   start-date  \
# 0                                    PhD in Computing    Fall 2021
# 1                                    PhD in Computing    Fall 2019
# 2                                    PhD in Computing    Fall 2020
# 3                                   MS in Mathematics          NaN
# 4                                   MS in Mathematics          NaN
# 5                                   MS in Mathematics          NaN
# 6                                   MS in Mathematics  Summer 2022
# 7                                   BS in Geosciences          NaN
# 8   BS in Applied Mathematics, Physics and Compute...          NaN
# 9             BS in Applied Mathematics and Economics          NaN
# 10                          BS in Applied Mathematics  Spring 2020
# 11                          BS in Applied Mathematics          NaN
# 12                                  BS in Geosciences          NaN
# 13                          BS in Applied Mathematics          NaN
# 14                       BS in Mechanical Engineering          NaN
# 15                          BS in Applied Mathematics          NaN
# 16                                  BS in Mathematics    Fall 2022
#
#    graduation-date                                            project  \
# 0          present  Work focused on developing ForestClaw for wild...
# 1          present  Work focused on direct elliptic solver using t...
# 2          present  Work focused on developing ForestClaw for atmo...
# 3      Spring 2017                                                NaN
# 4      Summer 2013                                                NaN
# 5      Summer 2012                                                NaN
# 6              NaN  Work on accelerating Clawpack solver on single...
# 7      Spring 2021  Develop computational model of the 1976 Teton ...
# 8      Spring 2020  Developed a multigrid solver for elliptic prob...
# 9      Spring 2021                Fractal formation in urban growth.
# 10             NaN  Tensor analysis on the sphere (HERC Fellowship...
# 11     Spring 2018  Worked on direct solver for 3d adaptive octree...
# 12       Fall 2017                                                NaN
# 13       Fall 2015  Senior Thesis project on implementing schemes ...
# 14       Fall 2015  Work with Idaho National Laboratory to develop...
# 15       Fall 2015  Google Earth visualization of tsunami activity...
# 16     Spring 2023                                 Senior 401 project
#
#                                                thesis  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   “Multi-rate Runge-Kutta-Chebyshev Time Steppin...
# 4   “Computing curvature and curvature normals on ...
# 5   “Perfect stripes from a general Turing model i...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  “Petrogenesis and Thermodynamic Modeling of Ma...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                          Automatic Differentiation
#
#                         funding  Unnamed: 9  Unnamed: 10
# 0                           NSF         NaN          NaN
# 1                           NSF         NaN          NaN
# 2                          NASA         NaN          NaN
# 3                           NSF         NaN          NaN
# 4            teaching assistant         NaN          NaN
# 5            teaching assistant         NaN          NaN
# 6            teaching assistant         NaN          NaN
# 7                           NSF         NaN          NaN
# 8                           NSF         NaN          NaN
# 9                           NaN         NaN          NaN
# 10  HERC Fellowship recipient.          NaN          NaN
# 11                          NSF         NaN          NaN
# 12                          NaN         NaN          NaN
# 13                          NaN         NaN          NaN
# 14                          NSF         NaN          NaN
# 15                          NaN         NaN          NaN
# 16                          NaN         NaN          NaN
# Index(['name-first', 'name-last', 'type', 'program', 'start-date',
#        'graduation-date', 'project', 'thesis', 'funding', 'Unnamed: 9',
#        'Unnamed: 10'],
#       dtype='object')

# %%
student_program_list = df.program.unique()
print(student_program_list)
# Out:
# ['PhD in Computing' 'MS in Mathematics' 'BS in Geosciences'
#  'BS in Applied Mathematics, Physics and Computer Science'
#  'BS in Applied Mathematics and Economics' 'BS in Applied Mathematics'
#  'BS in Mechanical Engineering' 'BS in Mathematics']

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
# df_journals = df[df['journal'].isnull() == False]
def single_quote(s):
    return "'" + s + "'"

def double_quote(s):
    return "\"" + s + "\""

def endl():
    return "\n"

def br():
    return "<br/>"

for row, item in df.iterrows():    
    first_name = item['name-first']
    last_name = item['name-last']
    fname = f"{first_name:}-{last_name:}"
    md_filename = f"{fname:}.md"
    html_filename = f"{fname:}.html"
    start_date = item['start-date']
    grad_date = item['graduation-date']

    
    
    ## YAML variables
    
    md = "---" + endl()
    # ------
    # name: 
    # ------
    md += "name: " + single_quote(f"{first_name:} {last_name:}") + endl()
    
    # -----------
    # collection: 
    # -----------
    md += "collection: students" + endl()

    # -----------
    # Type:
    # -----------

    md += "type: " + item['type'] + endl()
    
    # -----------
    # Program:
    # -----------
    
    md += "program: " + double_quote(item['program']) + endl()
    
    # ----------
    # permalink: 
    # ----------
    md += 'permalink: /students/' + html_filename + endl()
    
    # ---------
    # project:
    # ---------
    if not pd.isna(item['project']):
        md += "project: " + single_quote(html_escape(item['project'])) + endl()    
    elif not pd.isna(item['thesis']):
        md += "thesis: " + single_quote(html_escape(item['thesis'])) + endl()

    # ---------
    # funding:
    # ---------
    if not pd.isna(item['funding']):
        md += 'funding: ' + single_quote(item['funding']) + endl()
        
                
    # -----
    # date: 
    # -----
    
    if not pd.isna(item['start-date']):
        start_date = item['start-date']
        md += "dates: " + single_quote(start_date + ' - present') + endl()
    else:
        grad_date = item['graduation-date']
        md += "dates: " + single_quote(grad_date) + endl()
                        
    md += "---" + endl()
    
    
    print(fname)
    print("")

    
    # ----------------------------------------
    # Markdown description for individual page
    # ----------------------------------------
    
    # Put miscellaneous content here
    
    # md += ...
    
    # ----------------------------------------
    # Write out file name
    # ----------------------------------------

    md_filename = os.path.basename(md_filename)
       
    with open("../_students/" + md_filename, 'w') as f:
        f.write(md)    
        
print("Success!")
# Out:
# Patricia-Azike
#
# Damyn-Chipman
#
# Brian-Kyanjo
#
# Talin-Mirzakhanian
#
# John-Hutchins
#
# Jean-Schneider
#
# Gus-Tropea
#
# Hannah-Spero
#
# Scott-Aiton
#
# Tyler-Qualls
#
# Antone-Chacartegui
#
# Brenton-Peck
#
# Jordan-Engstrom
#
# Aaron-Solt
#
# Cody-Casteneda
#
# Stephanie-Potter
#
# Anthony-Jimenez
#
# Success!

# %%
print("Done")
# Out:
# Done
